# %%
#Write down a program in Python for Opening a File and writting "I Love Letsupgrade"And close it and read it back again and then append some data to it and close it

# %%
xyz =open("faisu.txt",'w')
xyz.write("I Love Letsupgrade")
xyz.close()

# %%
xyz =open("faisu.txt",'r')
content =xyz.read()
xyz.close()

# %%
content
# Out:
# 'I Love Letsupgrade'

# %%
xyz =open("faisu.txt",'a')
xyz.write("Hello everyone Have a nice day")
xyz.close()

# %%
#write a function which can return a factorial of any number as INT,given in the argument.

# %%
def fact(num):
    if(num==1):
        return 1
    F =num * fact(num-1)
    return F

# %%
fact(5)
# Out:
# 120

# %%
fact(3)
# Out:
# 6

# %%
fact(6)
# Out:
# 720

# %%
fact(1)
# Out:
# 1

# %%
fact(10)
# Out:
# 3628800
