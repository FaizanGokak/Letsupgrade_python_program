# %%
#Cryptography (Project1)

# %%
 # !pip install cryptography
# Out:
# ...
#      |████████████████████████████████| 2.6MB 8.7MB/s
# ...

# %%
 from cryptography.fernet import Fernet

# %%
 def genratePassKey():
    key = Fernet.generate_key()
    print(key)
    print(type(key))
    abc = open("PasswordKey.key",'wb')
    abc.write(key)
    abc.close()

# %%
 genratePassKey()
# Out:
# b'W1_DHrV15Ut3gt6_qQpIHJtLjlQUzaLLuLmCcKX1Y_0='
# <class 'bytes'>

# %%
 def getMyKey():
    abc = open("PasswordKey.key",'rb')
    return abc.read()

# %%
 getMyKey()
# Out:
# b'W1_DHrV15Ut3gt6_qQpIHJtLjlQUzaLLuLmCcKX1Y_0='

# %%
 
def getContentFromUser():
    return input("Enter the Content you want to Encrypt in your python Script")

# %%
 getContentFromUser()
# Out:
# Enter the Content you want to Encrypt in your python ScriptI love my INDIA
# 'I love my INDIA'

# %%
 def encryptMessage(message_normal):
    key = getMyKey()
    k = Fernet(key)
    encrypted_Message = k.encrypt(message_normal)
    return encrypted_Message

# %%
 encryptMessage(b" HEY THIS IS MY password 123451")
# Out:
# b'gAAAAABf3ckjsfF3sZPn6MoCSc3wMSUHHS_jTJ8hwP6mOkV8fJIDUHOE5WNehl2ETVixtrEpLyX6nM0O65IeG9ZEwPg43_F2GlhGveecmJ2VEnd98UhOspg='

# %%
 def decryptMessage(message_secret):
    key = getMyKey()
    k = Fernet(key)
    decrypted_Message = k.decrypt(message_secret)
    return decrypted_Message

# %%
 decryptMessage(b'gAAAAABf3ckjsfF3sZPn6MoCSc3wMSUHHS_jTJ8hwP6mOkV8fJIDUHOE5WNehl2ETVixtrEpLyX6nM0O65IeG9ZEwPg43_F2GlhGveecmJ2VEnd98UhOspg=')
# Out:
# b' HEY THIS IS MY password 123451'
