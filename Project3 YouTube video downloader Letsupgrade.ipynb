# %%
#Youtube Video downloader

# %%
# !pip install pytube
# Out:
# ...
#      |████████████████████████████████| 40kB 3.4MB/s
# ...

# %%
from pytube import YouTube

# %%
YouTube('https://youtu.be/aTOXb-lI6yc').streams.first().download ()
# Out:
# '/content/Shah Rukh Khans BEST motivational speech on his birthday.mp4'
